# %% [markdown]
# ## Brain Tumors Classification Using CNN

# %%
import os
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# %%
data_path = r'C:\Users\SaWa\Brain Tumors\Brain Tumors Data\brain_tumor_mri\new_dataset\bt_images'

# Construct full paths for the pickle files
training_data_path = os.path.join(data_path, r'C:\Users\SaWa\Brain Tumors\Brain Tumors Data\brain_tumor_mri\new_dataset\training_data.pickle')
labels_path = os.path.join(data_path, r'C:\Users\SaWa\Brain Tumors\Brain Tumors Data\brain_tumor_mri\new_dataset\labels.pickle')
test_data_path = os.path.join(data_path, r'C:\Users\SaWa\Brain Tumors\Brain Tumors Data\test_images-20210704T210303Z-001\test_images')

# Load the pickle files
with open(training_data_path, 'rb') as training_data_file:
    training_data = pickle.load(training_data_file)

with open(labels_path, 'rb') as labels_file:
    labels = pickle.load(labels_file)

# %%
from PIL import Image

# Open an image
image_path = r'C:\Users\SaWa\Brain Tumors\Brain Tumors Data\brain_tumor_mri\new_dataset\bt_images\1.jpg'
img = Image.open(image_path)

# Get the dimensions (width and height) of the image
width, height = img.size

print("Image Width:", width)
print("Image Height:", height)
# Out:
# Image Width: 512
# Image Height: 512

# %%
# Convert to NumPy arrays and normalize.
training_data = np.array(training_data)
labels = np.array(labels)
# Out:
# C:\Users\SaWa\AppData\Local\Temp\ipykernel_8952\1410008418.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training_data = np.array(training_data)

# %%
training_data.shape
# Out:
# (3064, 2)

# %%
labels.shape
# Out:
# (3064,)

# %%
unique_labels = np.unique(labels)
print("Unique Label Values:", unique_labels)
# Out:
# Unique Label Values: [1 2 3]

# %%
# Subtract 1 from each label to make them start from 0
adjusted_labels = labels - 1

# %%
unique_labels1 = np.unique(adjusted_labels)
print("Unique Label Values:", unique_labels1)
# Out:
# Unique Label Values: [0 1 2]

# %%
# Get a list of all files in the folder
file_list = os.listdir(data_path)

# %%
# Filter out only image files (e.g., JPG, PNG, etc.)
image_files = [file for file in file_list if file.lower().endswith(('.jpg', '.png', '.jpeg'))]

# %%
# List to store processed image data
image_data = []

for image_file in image_files:
    image_path = os.path.join(data_path, image_file)
    img = Image.open(image_path)
    
    # Convert to RGB format if not already
    img = img.convert('RGB')
    
    # Resize the image to the desired dimensions
    img = img.resize((224, 224))
    
    # Convert to NumPy array
    img_array = np.array(img)
    
    # Normalize pixel values and convert to NumPy array
    img_array = np.array(img) / 255.0  
    
    # Append the processed image array to the list
    image_data.append(img_array)

# %%
# Convert the list of processed image arrays to a NumPy array
images_array = np.array(image_data)

# %%
# Split data into training and testing sets
train_images, test_images, train_labels, test_labels = train_test_split(images_array, adjusted_labels, test_size=0.2, random_state=42)

# %%
del image_data

# %%
# Convert labels to categorical format
num_classes = len(np.unique(adjusted_labels))
train_labels_categorical = to_categorical(train_labels, num_classes=num_classes)
test_labels_categorical = to_categorical(test_labels, num_classes=num_classes)

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Define the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
batch_size = 32
epochs = 20

history = model.fit(train_images, train_labels_categorical,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(test_images, test_labels_categorical))
# Out:
# Epoch 1/20
# 77/77 [==============================] - 104s 1s/step - loss: 0.7304 - accuracy: 0.6756 - val_loss: 0.5931 - val_accuracy: 0.7651
# Epoch 2/20
# 77/77 [==============================] - 101s 1s/step - loss: 0.5297 - accuracy: 0.7858 - val_loss: 0.5077 - val_accuracy: 0.7847
# Epoch 3/20
# 77/77 [==============================] - 102s 1s/step - loss: 0.4217 - accuracy: 0.8380 - val_loss: 0.3984 - val_accuracy: 0.8254
# Epoch 4/20
# 77/77 [==============================] - 105s 1s/step - loss: 0.3535 - accuracy: 0.8605 - val_loss: 0.3272 - val_accuracy: 0.8695
# Epoch 5/20
# 77/77 [==============================] - 104s 1s/step - loss: 0.2813 - accuracy: 0.8935 - val_loss: 0.3280 - val_accuracy: 0.8711
# Epoch 6/20
# 77/77 [==============================] - 102s 1s/step - loss: 0.2452 - accuracy: 0.9082 - val_loss: 0.2658 - val_accuracy: 0.9005
# Epoch 7/20
# 77/77 [==============================] - 102s 1s/step - loss: 0.2015 - accuracy: 0.9257 - val_loss: 0.2650 - val_accuracy: 0.8956
# Epoch 8/20
# 77/77 [==============================] - 102s 1s/step - loss: 0.1691 - accuracy: 0.9392 - val_loss: 0.2325 - val_accuracy: 0.9184
# Epoch 9/20
# 77/77 [==============================] - 102s 1s/step - loss: 0.1196 - accuracy: 0.9568 - val_loss: 0.2294 - val_accuracy: 0.9233
# Epoch 10/20
# 77/77 [==============================] - 103s 1s/step - loss: 0.1029 - accuracy: 0.9657 - val_loss: 0.2404 - val_accuracy: 0.9217
# Epoch 11/20
# 77/77 [==============================] - 103s 1s/step - loss: 0.0794 - accuracy: 0.9755 - val_loss: 0.2275 - val_accuracy: 0.9266
# Epoch 12/20
# 77/77 [==============================] - 104s 1s/step - loss: 0.0722 - accuracy: 0.9759 - val_loss: 0.2072 - val_accuracy: 0.9331
# Epoch 13/20
# 77/77 [==============================] - 103s 1s/step - loss: 0.0513 - accuracy: 0.9857 - val_loss: 0.2264 - val_accuracy: 0.9380
# Epoch 14/20
# 77/77 [==============================] - 103s 1s/step - loss: 0.0488 - accuracy: 0.9853 - val_loss: 0.2350 - val_accuracy: 0.9282
# Epoch 15/20
# 77/77 [==============================] - 104s 1s/step - loss: 0.0427 - accuracy: 0.9865 - val_loss: 0.2240 - val_accuracy: 0.9282
# Epoch 16/20
# 77/77 [==============================] - 104s 1s/step - loss: 0.0378 - accuracy: 0.9865 - val_loss: 0.2207 - val_accuracy: 0.9429
# Epoch 17/20
# 77/77 [==============================] - 105s 1s/step - loss: 0.0422 - accuracy: 0.9845 - val_loss: 0.2552 - val_accuracy: 0.9282
# Epoch 18/20
# 77/77 [==============================] - 104s 1s/step - loss: 0.0276 - accuracy: 0.9935 - val_loss: 0.2298 - val_accuracy: 0.9364
# Epoch 19/20
# 77/77 [==============================] - 103s 1s/step - loss: 0.0314 - accuracy: 0.9902 - val_loss: 0.2093 - val_accuracy: 0.9364
# Epoch 20/20
# 77/77 [==============================] - 103s 1s/step - loss: 0.0181 - accuracy: 0.9959 - val_loss: 0.2203 - val_accuracy: 0.9445

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_images, test_labels_categorical, verbose=2)
print("Test accuracy:", test_accuracy)
# Out:
# 20/20 - 6s - loss: 0.2203 - accuracy: 0.9445 - 6s/epoch - 284ms/step
# Test accuracy: 0.9445350766181946

# %% [markdown]
# ### Evaluation using confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

# Assuming you have predictions from your model
predictions = model.predict(test_images)
predicted_labels = np.argmax(predictions, axis=1)  # Convert one-hot encoded predictions to labels

# Assuming test_labels_categorical contains the true labels in one-hot encoded format
true_labels = np.argmax(test_labels_categorical, axis=1)

# Generate confusion matrix
confusion = confusion_matrix(true_labels, predicted_labels)

print("Confusion Matrix:")
print(confusion)
# Out:
# 20/20 [==============================] - 6s 269ms/step
# Confusion Matrix:
# [[152   6   3]
#  [  6 253  10]
#  [  2   7 174]]

# %% [markdown]
# ### Evaluation using area under the curve

# %%
from sklearn.metrics import roc_auc_score

# Assuming you have predictions from your model
predictions = model.predict(test_images)

# Assuming test_labels_categorical contains the true labels in one-hot encoded format
true_labels = test_labels_categorical[:, 1]  # Assuming the positive class is index 1

# Calculate AUC
auc = roc_auc_score(true_labels, predictions[:, 1])  # Assuming the positive class is index 1

# Print AUC and test accuracy
print("AUC:", auc)
print("Test accuracy:", test_accuracy)
# Out:
# 20/20 [==============================] - 5s 255ms/step
# AUC: 0.9891609751880349
# Test accuracy: 0.9445350766181946

# %% [markdown]
# ### Graph for loss and accuracy

# %%
import matplotlib.pyplot as plt 

# Get training history
train_loss = history.history['loss']
train_accuracy = history.history['accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_accuracy']

# Plot loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot accuracy
plt.subplot(1, 2, 2)
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Precision, Recall, F1 score from classification report

# %%
from sklearn.metrics import classification_report

# Assuming you have predictions from your model
predictions = model.predict(test_images)

true_labels = np.argmax(test_labels_categorical, axis=1)

# Generate classification report
class_names = ["Pituitary", "Meningioma", "Glioma"]  
report = classification_report(true_labels, np.argmax(predictions, axis=1), target_names=class_names)

print("Classification Report:\n", report)
# Out:
# 20/20 [==============================] - 5s 225ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#    Pituitary       0.95      0.94      0.95       161
#   Meningioma       0.95      0.94      0.95       269
#       Glioma       0.93      0.95      0.94       183
#
#     accuracy                           0.94       613
#    macro avg       0.94      0.95      0.94       613
# weighted avg       0.94      0.94      0.94       613

# %% [markdown]
# ### Calculate Confidence

# %%
import numpy as np
# Get the maximum probability for each prediction
max_probabilities = np.max(predictions, axis=1)

# Print the confidence scores for the first few test images
for i in range(len(max_probabilities)):
    print(f"Test Image {i + 1} - Confidence: {max_probabilities[i]:.4f}")
# Out:
# Test Image 1 - Confidence: 0.9996
# Test Image 2 - Confidence: 0.9966
# Test Image 3 - Confidence: 0.9998
# Test Image 4 - Confidence: 0.9737
# Test Image 5 - Confidence: 0.9969
# Test Image 6 - Confidence: 0.9999
# Test Image 7 - Confidence: 0.9995
# Test Image 8 - Confidence: 0.9813
# Test Image 9 - Confidence: 1.0000
# Test Image 10 - Confidence: 0.9997
# Test Image 11 - Confidence: 0.9795
# Test Image 12 - Confidence: 1.0000
# Test Image 13 - Confidence: 0.9920
# Test Image 14 - Confidence: 0.9791
# Test Image 15 - Confidence: 0.9957
# Test Image 16 - Confidence: 0.9999
# Test Image 17 - Confidence: 0.9998
# Test Image 18 - Confidence: 1.0000
# Test Image 19 - Confidence: 0.9998
# Test Image 20 - Confidence: 1.0000
# Test Image 21 - Confidence: 1.0000
# Test Image 22 - Confidence: 0.9992
# Test Image 23 - Confidence: 0.9984
# Test Image 24 - Confidence: 0.9987
# Test Image 25 - Confidence: 1.0000
# Test Image 26 - Confidence: 0.9989
# Test Image 27 - Confidence: 0.9999
# Test Image 28 - Confidence: 0.9986
# Test Image 29 - Confidence: 1.0000
# Test Image 30 - Confidence: 0.9783
# Test Image 31 - Confidence: 1.0000
# Test Image 32 - Confidence: 0.9999
# Test Image 33 - Confidence: 1.0000
# Test Image 34 - Confidence: 0.9998
# Test Image 35 - Confidence: 0.9985
# Test Image 36 - Confidence: 0.9993
# Test Image 37 - Confidence: 1.0000
# Test Image 38 - Confidence: 0.6801
# Test Image 39 - Confidence: 0.9961
# Test Image 40 - Confidence: 0.9915
# Test Image 41 - Confidence: 0.9996
# Test Image 42 - Confidence: 0.9992
# Test Image 43 - Confidence: 0.9999
# Test Image 44 - Confidence: 1.0000
# Test Image 45 - Confidence: 0.9993
# Test Image 46 - Confidence: 0.9607
# Test Image 47 - Confidence: 0.9710
# Test Image 48 - Confidence: 0.9980
# Test Image 49 - Confidence: 1.0000
# Test Image 50 - Confidence: 1.0000
# Test Image 51 - Confidence: 0.9995
# Test Image 52 - Confidence: 0.6783
# Test Image 53 - Confidence: 0.9847
# Test Image 54 - Confidence: 0.9726
# Test Image 55 - Confidence: 0.9995
# Test Image 56 - Confidence: 0.9999
# Test Image 57 - Confidence: 1.0000
# Test Image 58 - Confidence: 0.9324
# Test Image 59 - Confidence: 1.0000
# Test Image 60 - Confidence: 1.0000
# Test Image 61 - Confidence: 1.0000
# Test Image 62 - Confidence: 0.9957
# Test Image 63 - Confidence: 0.9957
# Test Image 64 - Confidence: 0.9921
# Test Image 65 - Confidence: 0.9934
# Test Image 66 - Confidence: 0.9931
# Test Image 67 - Confidence: 0.5982
# Test Image 68 - Confidence: 1.0000
# Test Image 69 - Confidence: 0.9998
# Test Image 70 - Confidence: 1.0000
# Test Image 71 - Confidence: 0.9991
# Test Image 72 - Confidence: 1.0000
# Test Image 73 - Confidence: 0.9998
# Test Image 74 - Confidence: 0.9994
# Test Image 75 - Confidence: 0.9999
# Test Image 76 - Confidence: 0.9956
# Test Image 77 - Confidence: 0.9995
# Test Image 78 - Confidence: 0.9720
# Test Image 79 - Confidence: 0.9792
# Test Image 80 - Confidence: 1.0000
# Test Image 81 - Confidence: 1.0000
# Test Image 82 - Confidence: 1.0000
# Test Image 83 - Confidence: 0.9938
# Test Image 84 - Confidence: 1.0000
# Test Image 85 - Confidence: 0.9999
# Test Image 86 - Confidence: 0.9997
# Test Image 87 - Confidence: 1.0000
# Test Image 88 - Confidence: 1.0000
# Test Image 89 - Confidence: 0.9999
# Test Image 90 - Confidence: 0.9989
# Test Image 91 - Confidence: 1.0000
# Test Image 92 - Confidence: 0.9958
# Test Image 93 - Confidence: 1.0000
# Test Image 94 - Confidence: 1.0000
# Test Image 95 - Confidence: 0.9978
# Test Image 96 - Confidence: 0.9999
# Test Image 97 - Confidence: 1.0000
# Test Image 98 - Confidence: 1.0000
# Test Image 99 - Confidence: 1.0000
# Test Image 100 - Confidence: 1.0000
# Test Image 101 - Confidence: 1.0000
# Test Image 102 - Confidence: 1.0000
# Test Image 103 - Confidence: 0.9975
# Test Image 104 - Confidence: 0.9485
# Test Image 105 - Confidence: 0.8038
# Test Image 106 - Confidence: 1.0000
# Test Image 107 - Confidence: 0.9943
# Test Image 108 - Confidence: 0.9999
# Test Image 109 - Confidence: 0.9999
# Test Image 110 - Confidence: 0.9997
# Test Image 111 - Confidence: 0.9967
# Test Image 112 - Confidence: 0.5946
# Test Image 113 - Confidence: 0.9402
# Test Image 114 - Confidence: 1.0000
# Test Image 115 - Confidence: 1.0000
# Test Image 116 - Confidence: 0.9997
# Test Image 117 - Confidence: 0.5239
# Test Image 118 - Confidence: 1.0000
# Test Image 119 - Confidence: 0.9999
# Test Image 120 - Confidence: 1.0000
# Test Image 121 - Confidence: 1.0000
# Test Image 122 - Confidence: 1.0000
# Test Image 123 - Confidence: 0.9974
# Test Image 124 - Confidence: 0.9980
# Test Image 125 - Confidence: 1.0000
# Test Image 126 - Confidence: 0.9986
# Test Image 127 - Confidence: 0.9981
# Test Image 128 - Confidence: 0.9959
# Test Image 129 - Confidence: 0.9973
# Test Image 130 - Confidence: 0.9999
# Test Image 131 - Confidence: 0.9857
# Test Image 132 - Confidence: 0.9781
# Test Image 133 - Confidence: 0.6932
# Test Image 134 - Confidence: 0.9996
# Test Image 135 - Confidence: 0.9961
# Test Image 136 - Confidence: 0.9992
# Test Image 137 - Confidence: 0.9736
# Test Image 138 - Confidence: 0.9999
# Test Image 139 - Confidence: 0.9990
# Test Image 140 - Confidence: 0.9992
# Test Image 141 - Confidence: 0.9881
# Test Image 142 - Confidence: 1.0000
# Test Image 143 - Confidence: 0.9981
# Test Image 144 - Confidence: 0.9988
# Test Image 145 - Confidence: 0.9999
# Test Image 146 - Confidence: 0.9960
# Test Image 147 - Confidence: 1.0000
# Test Image 148 - Confidence: 0.9995
# Test Image 149 - Confidence: 1.0000
# Test Image 150 - Confidence: 0.9986
# Test Image 151 - Confidence: 0.9914
# Test Image 152 - Confidence: 1.0000
# Test Image 153 - Confidence: 0.9969
# Test Image 154 - Confidence: 0.8292
# Test Image 155 - Confidence: 0.9994
# Test Image 156 - Confidence: 1.0000
# Test Image 157 - Confidence: 0.9934
# Test Image 158 - Confidence: 1.0000
# Test Image 159 - Confidence: 0.9993
# Test Image 160 - Confidence: 0.9952
# Test Image 161 - Confidence: 0.5580
# Test Image 162 - Confidence: 0.9988
# Test Image 163 - Confidence: 0.9950
# Test Image 164 - Confidence: 0.9895
# Test Image 165 - Confidence: 0.5330
# Test Image 166 - Confidence: 0.9999
# Test Image 167 - Confidence: 0.9998
# Test Image 168 - Confidence: 0.9996
# Test Image 169 - Confidence: 0.9941
# Test Image 170 - Confidence: 0.5594
# Test Image 171 - Confidence: 0.9811
# Test Image 172 - Confidence: 0.9970
# Test Image 173 - Confidence: 0.9972
# Test Image 174 - Confidence: 0.9999
# Test Image 175 - Confidence: 1.0000
# Test Image 176 - Confidence: 0.9999
# Test Image 177 - Confidence: 0.9268
# Test Image 178 - Confidence: 1.0000
# Test Image 179 - Confidence: 0.9906
# Test Image 180 - Confidence: 1.0000
# Test Image 181 - Confidence: 1.0000
# Test Image 182 - Confidence: 0.9777
# Test Image 183 - Confidence: 0.9999
# Test Image 184 - Confidence: 0.7033
# Test Image 185 - Confidence: 1.0000
# Test Image 186 - Confidence: 0.4761
# Test Image 187 - Confidence: 0.9983
# Test Image 188 - Confidence: 0.9987
# Test Image 189 - Confidence: 0.6758
# Test Image 190 - Confidence: 0.8271
# Test Image 191 - Confidence: 0.9979
# Test Image 192 - Confidence: 1.0000
# Test Image 193 - Confidence: 0.9993
# Test Image 194 - Confidence: 1.0000
# Test Image 195 - Confidence: 1.0000
# Test Image 196 - Confidence: 0.9808
# Test Image 197 - Confidence: 1.0000
# Test Image 198 - Confidence: 0.7354
# Test Image 199 - Confidence: 1.0000
# Test Image 200 - Confidence: 0.9117
# Test Image 201 - Confidence: 1.0000
# Test Image 202 - Confidence: 0.9917
# Test Image 203 - Confidence: 0.9998
# Test Image 204 - Confidence: 1.0000
# Test Image 205 - Confidence: 1.0000
# Test Image 206 - Confidence: 0.8519
# Test Image 207 - Confidence: 1.0000
# Test Image 208 - Confidence: 0.9989
# Test Image 209 - Confidence: 1.0000
# Test Image 210 - Confidence: 1.0000
# Test Image 211 - Confidence: 0.9995
# Test Image 212 - Confidence: 1.0000
# Test Image 213 - Confidence: 1.0000
# Test Image 214 - Confidence: 0.6339
# Test Image 215 - Confidence: 0.9999
# Test Image 216 - Confidence: 0.9965
# Test Image 217 - Confidence: 0.9994
# Test Image 218 - Confidence: 0.9999
# Test Image 219 - Confidence: 0.9796
# Test Image 220 - Confidence: 0.9919
# Test Image 221 - Confidence: 0.9684
# Test Image 222 - Confidence: 1.0000
# Test Image 223 - Confidence: 1.0000
# Test Image 224 - Confidence: 0.9751
# Test Image 225 - Confidence: 1.0000
# Test Image 226 - Confidence: 0.9999
# Test Image 227 - Confidence: 1.0000
# Test Image 228 - Confidence: 0.9695
# Test Image 229 - Confidence: 1.0000
# Test Image 230 - Confidence: 1.0000
# Test Image 231 - Confidence: 0.9919
# Test Image 232 - Confidence: 0.9998
# Test Image 233 - Confidence: 1.0000
# Test Image 234 - Confidence: 0.9989
# Test Image 235 - Confidence: 1.0000
# Test Image 236 - Confidence: 1.0000
# Test Image 237 - Confidence: 0.6787
# Test Image 238 - Confidence: 0.9977
# Test Image 239 - Confidence: 0.9988
# Test Image 240 - Confidence: 0.9881
# Test Image 241 - Confidence: 0.9999
# Test Image 242 - Confidence: 0.9998
# Test Image 243 - Confidence: 1.0000
# Test Image 244 - Confidence: 0.9894
# Test Image 245 - Confidence: 0.9997
# Test Image 246 - Confidence: 0.9999
# Test Image 247 - Confidence: 0.9986
# Test Image 248 - Confidence: 0.9999
# Test Image 249 - Confidence: 0.9997
# Test Image 250 - Confidence: 1.0000
# Test Image 251 - Confidence: 1.0000
# Test Image 252 - Confidence: 1.0000
# Test Image 253 - Confidence: 0.9976
# Test Image 254 - Confidence: 0.9485
# Test Image 255 - Confidence: 0.9987
# Test Image 256 - Confidence: 0.9999
# Test Image 257 - Confidence: 0.9936
# Test Image 258 - Confidence: 1.0000
# Test Image 259 - Confidence: 0.9946
# Test Image 260 - Confidence: 0.9876
# Test Image 261 - Confidence: 0.9993
# Test Image 262 - Confidence: 1.0000
# Test Image 263 - Confidence: 1.0000
# Test Image 264 - Confidence: 0.6968
# Test Image 265 - Confidence: 1.0000
# Test Image 266 - Confidence: 1.0000
# Test Image 267 - Confidence: 0.9982
# Test Image 268 - Confidence: 1.0000
# Test Image 269 - Confidence: 1.0000
# Test Image 270 - Confidence: 0.9993
# Test Image 271 - Confidence: 0.9974
# Test Image 272 - Confidence: 0.9211
# Test Image 273 - Confidence: 1.0000
# Test Image 274 - Confidence: 0.9969
# Test Image 275 - Confidence: 1.0000
# Test Image 276 - Confidence: 0.9898
# Test Image 277 - Confidence: 1.0000
# Test Image 278 - Confidence: 0.9205
# Test Image 279 - Confidence: 1.0000
# Test Image 280 - Confidence: 0.7675
# Test Image 281 - Confidence: 1.0000
# Test Image 282 - Confidence: 0.9590
# Test Image 283 - Confidence: 1.0000
# Test Image 284 - Confidence: 1.0000
# Test Image 285 - Confidence: 0.9886
# Test Image 286 - Confidence: 0.9977
# Test Image 287 - Confidence: 0.9997
# Test Image 288 - Confidence: 0.9999
# Test Image 289 - Confidence: 0.9994
# Test Image 290 - Confidence: 1.0000
# Test Image 291 - Confidence: 0.9165
# Test Image 292 - Confidence: 1.0000
# Test Image 293 - Confidence: 0.9991
# Test Image 294 - Confidence: 1.0000
# Test Image 295 - Confidence: 0.9989
# Test Image 296 - Confidence: 0.9998
# Test Image 297 - Confidence: 1.0000
# Test Image 298 - Confidence: 0.9999
# Test Image 299 - Confidence: 0.9929
# Test Image 300 - Confidence: 0.9999
# Test Image 301 - Confidence: 0.9933
# Test Image 302 - Confidence: 0.9999
# Test Image 303 - Confidence: 0.9998
# Test Image 304 - Confidence: 0.9974
# Test Image 305 - Confidence: 0.9997
# Test Image 306 - Confidence: 0.6070
# Test Image 307 - Confidence: 0.9905
# Test Image 308 - Confidence: 0.9957
# Test Image 309 - Confidence: 0.5190
# Test Image 310 - Confidence: 1.0000
# Test Image 311 - Confidence: 1.0000
# Test Image 312 - Confidence: 0.9999
# Test Image 313 - Confidence: 0.9999
# Test Image 314 - Confidence: 0.9932
# Test Image 315 - Confidence: 0.9997
# Test Image 316 - Confidence: 0.9584
# Test Image 317 - Confidence: 0.9987
# Test Image 318 - Confidence: 0.8251
# Test Image 319 - Confidence: 0.9926
# Test Image 320 - Confidence: 0.6739
# Test Image 321 - Confidence: 0.9852
# Test Image 322 - Confidence: 0.9999
# Test Image 323 - Confidence: 1.0000
# Test Image 324 - Confidence: 0.9993
# Test Image 325 - Confidence: 0.9963
# Test Image 326 - Confidence: 0.6716
# Test Image 327 - Confidence: 0.9988
# Test Image 328 - Confidence: 1.0000
# Test Image 329 - Confidence: 1.0000
# Test Image 330 - Confidence: 0.5239
# Test Image 331 - Confidence: 1.0000
# Test Image 332 - Confidence: 0.9973
# Test Image 333 - Confidence: 0.8997
# Test Image 334 - Confidence: 1.0000
# Test Image 335 - Confidence: 0.9999
# Test Image 336 - Confidence: 0.9999
# Test Image 337 - Confidence: 0.9787
# Test Image 338 - Confidence: 0.5459
# Test Image 339 - Confidence: 0.9445
# Test Image 340 - Confidence: 1.0000
# Test Image 341 - Confidence: 0.9618
# Test Image 342 - Confidence: 0.9997
# Test Image 343 - Confidence: 1.0000
# Test Image 344 - Confidence: 1.0000
# Test Image 345 - Confidence: 0.9989
# Test Image 346 - Confidence: 0.9999
# Test Image 347 - Confidence: 1.0000
# Test Image 348 - Confidence: 1.0000
# Test Image 349 - Confidence: 0.9995
# Test Image 350 - Confidence: 0.8562
# Test Image 351 - Confidence: 0.9884
# Test Image 352 - Confidence: 0.9981
# Test Image 353 - Confidence: 0.9994
# Test Image 354 - Confidence: 0.9995
# Test Image 355 - Confidence: 1.0000
# Test Image 356 - Confidence: 1.0000
# Test Image 357 - Confidence: 0.6563
# Test Image 358 - Confidence: 0.9718
# Test Image 359 - Confidence: 1.0000
# Test Image 360 - Confidence: 1.0000
# Test Image 361 - Confidence: 1.0000
# Test Image 362 - Confidence: 1.0000
# Test Image 363 - Confidence: 0.9885
# Test Image 364 - Confidence: 1.0000
# Test Image 365 - Confidence: 0.9968
# Test Image 366 - Confidence: 0.9991
# Test Image 367 - Confidence: 0.8319
# Test Image 368 - Confidence: 0.6838
# Test Image 369 - Confidence: 0.9996
# Test Image 370 - Confidence: 1.0000
# Test Image 371 - Confidence: 0.9999
# Test Image 372 - Confidence: 1.0000
# Test Image 373 - Confidence: 0.9999
# Test Image 374 - Confidence: 0.9907
# Test Image 375 - Confidence: 1.0000
# Test Image 376 - Confidence: 1.0000
# Test Image 377 - Confidence: 1.0000
# Test Image 378 - Confidence: 0.9984
# Test Image 379 - Confidence: 1.0000
# Test Image 380 - Confidence: 1.0000
# Test Image 381 - Confidence: 1.0000
# Test Image 382 - Confidence: 0.9606
# Test Image 383 - Confidence: 0.9646
# Test Image 384 - Confidence: 0.9966
# Test Image 385 - Confidence: 0.9994
# Test Image 386 - Confidence: 0.9999
# Test Image 387 - Confidence: 0.9500
# Test Image 388 - Confidence: 1.0000
# Test Image 389 - Confidence: 0.5208
# Test Image 390 - Confidence: 0.9365
# Test Image 391 - Confidence: 0.8338
# Test Image 392 - Confidence: 0.9998
# Test Image 393 - Confidence: 0.9857
# Test Image 394 - Confidence: 0.9989
# Test Image 395 - Confidence: 1.0000
# Test Image 396 - Confidence: 0.9994
# Test Image 397 - Confidence: 0.9993
# Test Image 398 - Confidence: 0.9991
# Test Image 399 - Confidence: 1.0000
# Test Image 400 - Confidence: 0.9990
# Test Image 401 - Confidence: 0.9996
# Test Image 402 - Confidence: 0.9999
# Test Image 403 - Confidence: 1.0000
# Test Image 404 - Confidence: 0.9999
# Test Image 405 - Confidence: 0.8715
# Test Image 406 - Confidence: 0.9989
# Test Image 407 - Confidence: 0.9985
# Test Image 408 - Confidence: 0.9706
# Test Image 409 - Confidence: 0.8414
# Test Image 410 - Confidence: 1.0000
# Test Image 411 - Confidence: 1.0000
# Test Image 412 - Confidence: 0.9997
# Test Image 413 - Confidence: 0.4987
# Test Image 414 - Confidence: 1.0000
# Test Image 415 - Confidence: 1.0000
# Test Image 416 - Confidence: 0.9997
# Test Image 417 - Confidence: 0.9958
# Test Image 418 - Confidence: 0.9992
# Test Image 419 - Confidence: 1.0000
# Test Image 420 - Confidence: 1.0000
# Test Image 421 - Confidence: 1.0000
# Test Image 422 - Confidence: 0.9991
# Test Image 423 - Confidence: 1.0000
# Test Image 424 - Confidence: 0.9999
# Test Image 425 - Confidence: 1.0000
# Test Image 426 - Confidence: 1.0000
# Test Image 427 - Confidence: 1.0000
# Test Image 428 - Confidence: 0.9979
# Test Image 429 - Confidence: 1.0000
# Test Image 430 - Confidence: 0.9322
# Test Image 431 - Confidence: 0.9999
# Test Image 432 - Confidence: 0.9901
# Test Image 433 - Confidence: 1.0000
# Test Image 434 - Confidence: 0.9999
# Test Image 435 - Confidence: 0.9850
# Test Image 436 - Confidence: 0.9986
# Test Image 437 - Confidence: 1.0000
# Test Image 438 - Confidence: 0.9995
# Test Image 439 - Confidence: 0.9506
# Test Image 440 - Confidence: 0.9993
# Test Image 441 - Confidence: 0.5944
# Test Image 442 - Confidence: 1.0000
# Test Image 443 - Confidence: 0.7711
# Test Image 444 - Confidence: 0.9999
# Test Image 445 - Confidence: 0.9880
# Test Image 446 - Confidence: 1.0000
# Test Image 447 - Confidence: 0.9790
# Test Image 448 - Confidence: 0.9774
# Test Image 449 - Confidence: 0.8569
# Test Image 450 - Confidence: 0.9841
# Test Image 451 - Confidence: 0.9995
# Test Image 452 - Confidence: 1.0000
# Test Image 453 - Confidence: 0.9653
# Test Image 454 - Confidence: 0.9699
# Test Image 455 - Confidence: 0.9987
# Test Image 456 - Confidence: 0.8647
# Test Image 457 - Confidence: 0.9999
# Test Image 458 - Confidence: 1.0000
# Test Image 459 - Confidence: 1.0000
# Test Image 460 - Confidence: 1.0000
# Test Image 461 - Confidence: 0.9958
# Test Image 462 - Confidence: 1.0000
# Test Image 463 - Confidence: 0.9990
# Test Image 464 - Confidence: 1.0000
# Test Image 465 - Confidence: 0.9999
# Test Image 466 - Confidence: 0.9984
# Test Image 467 - Confidence: 0.9347
# Test Image 468 - Confidence: 0.9405
# Test Image 469 - Confidence: 0.9974
# Test Image 470 - Confidence: 0.9990
# Test Image 471 - Confidence: 1.0000
# Test Image 472 - Confidence: 1.0000
# Test Image 473 - Confidence: 0.8549
# Test Image 474 - Confidence: 1.0000
# Test Image 475 - Confidence: 0.9908
# Test Image 476 - Confidence: 0.9999
# Test Image 477 - Confidence: 1.0000
# Test Image 478 - Confidence: 0.9879
# Test Image 479 - Confidence: 0.6713
# Test Image 480 - Confidence: 0.9993
# Test Image 481 - Confidence: 0.9991
# Test Image 482 - Confidence: 0.9877
# Test Image 483 - Confidence: 0.9997
# Test Image 484 - Confidence: 1.0000
# Test Image 485 - Confidence: 0.8275
# Test Image 486 - Confidence: 0.9997
# Test Image 487 - Confidence: 0.9999
# Test Image 488 - Confidence: 0.8552
# Test Image 489 - Confidence: 0.9999
# Test Image 490 - Confidence: 0.9554
# Test Image 491 - Confidence: 0.7385
# Test Image 492 - Confidence: 0.9912
# Test Image 493 - Confidence: 0.9999
# Test Image 494 - Confidence: 1.0000
# Test Image 495 - Confidence: 0.7814
# Test Image 496 - Confidence: 0.9345
# Test Image 497 - Confidence: 1.0000
# Test Image 498 - Confidence: 1.0000
# Test Image 499 - Confidence: 0.9981
# Test Image 500 - Confidence: 1.0000
# Test Image 501 - Confidence: 0.9990
# Test Image 502 - Confidence: 1.0000
# Test Image 503 - Confidence: 0.9998
# Test Image 504 - Confidence: 0.9978
# Test Image 505 - Confidence: 0.9996
# Test Image 506 - Confidence: 0.9986
# Test Image 507 - Confidence: 0.9994
# Test Image 508 - Confidence: 0.8531
# Test Image 509 - Confidence: 0.9895
# Test Image 510 - Confidence: 0.9991
# Test Image 511 - Confidence: 0.6759
# Test Image 512 - Confidence: 0.9054
# Test Image 513 - Confidence: 0.9998
# Test Image 514 - Confidence: 1.0000
# Test Image 515 - Confidence: 0.9996
# Test Image 516 - Confidence: 0.9980
# Test Image 517 - Confidence: 1.0000
# Test Image 518 - Confidence: 0.9990
# Test Image 519 - Confidence: 0.9991
# Test Image 520 - Confidence: 0.9995
# Test Image 521 - Confidence: 0.9496
# Test Image 522 - Confidence: 0.9999
# Test Image 523 - Confidence: 0.9760
# Test Image 524 - Confidence: 0.9997
# Test Image 525 - Confidence: 0.9983
# Test Image 526 - Confidence: 1.0000
# Test Image 527 - Confidence: 1.0000
# Test Image 528 - Confidence: 0.9931
# Test Image 529 - Confidence: 0.9999
# Test Image 530 - Confidence: 1.0000
# Test Image 531 - Confidence: 0.9992
# Test Image 532 - Confidence: 0.9612
# Test Image 533 - Confidence: 0.9989
# Test Image 534 - Confidence: 1.0000
# Test Image 535 - Confidence: 1.0000
# Test Image 536 - Confidence: 0.9780
# Test Image 537 - Confidence: 0.9967
# Test Image 538 - Confidence: 0.9263
# Test Image 539 - Confidence: 0.9972
# Test Image 540 - Confidence: 0.9979
# Test Image 541 - Confidence: 1.0000
# Test Image 542 - Confidence: 0.9999
# Test Image 543 - Confidence: 0.5400
# Test Image 544 - Confidence: 0.9990
# Test Image 545 - Confidence: 1.0000
# Test Image 546 - Confidence: 0.9992
# Test Image 547 - Confidence: 1.0000
# Test Image 548 - Confidence: 0.9957
# Test Image 549 - Confidence: 0.9900
# Test Image 550 - Confidence: 0.9991
# Test Image 551 - Confidence: 1.0000
# Test Image 552 - Confidence: 0.9998
# Test Image 553 - Confidence: 0.9946
# Test Image 554 - Confidence: 0.9995
# Test Image 555 - Confidence: 1.0000
# Test Image 556 - Confidence: 1.0000
# Test Image 557 - Confidence: 1.0000
# Test Image 558 - Confidence: 0.9998
# Test Image 559 - Confidence: 0.9999
# Test Image 560 - Confidence: 1.0000
# Test Image 561 - Confidence: 0.9876
# Test Image 562 - Confidence: 1.0000
# Test Image 563 - Confidence: 0.9999
# Test Image 564 - Confidence: 0.7971
# Test Image 565 - Confidence: 0.9986
# Test Image 566 - Confidence: 0.7088
# Test Image 567 - Confidence: 1.0000
# Test Image 568 - Confidence: 1.0000
# Test Image 569 - Confidence: 1.0000
# Test Image 570 - Confidence: 1.0000
# Test Image 571 - Confidence: 0.9989
# Test Image 572 - Confidence: 0.9566
# Test Image 573 - Confidence: 0.9665
# Test Image 574 - Confidence: 0.9916
# Test Image 575 - Confidence: 0.9997
# Test Image 576 - Confidence: 0.9999
# Test Image 577 - Confidence: 1.0000
# Test Image 578 - Confidence: 0.9997
# Test Image 579 - Confidence: 1.0000
# Test Image 580 - Confidence: 1.0000
# Test Image 581 - Confidence: 1.0000
# Test Image 582 - Confidence: 1.0000
# Test Image 583 - Confidence: 0.9996
# Test Image 584 - Confidence: 1.0000
# Test Image 585 - Confidence: 0.9943
# Test Image 586 - Confidence: 0.9916
# Test Image 587 - Confidence: 0.9998
# Test Image 588 - Confidence: 0.9979
# Test Image 589 - Confidence: 0.8178
# Test Image 590 - Confidence: 0.9141
# Test Image 591 - Confidence: 0.9997
# Test Image 592 - Confidence: 0.9998
# Test Image 593 - Confidence: 0.9999
# Test Image 594 - Confidence: 0.8992
# Test Image 595 - Confidence: 0.9994
# Test Image 596 - Confidence: 0.9961
# Test Image 597 - Confidence: 0.9309
# Test Image 598 - Confidence: 0.9717
# Test Image 599 - Confidence: 0.9995
# Test Image 600 - Confidence: 0.9998
# Test Image 601 - Confidence: 0.9035
# Test Image 602 - Confidence: 0.9999
# Test Image 603 - Confidence: 0.9601
# Test Image 604 - Confidence: 0.7594
# Test Image 605 - Confidence: 1.0000
# Test Image 606 - Confidence: 1.0000
# Test Image 607 - Confidence: 0.9965
# Test Image 608 - Confidence: 0.9933
# Test Image 609 - Confidence: 1.0000
# Test Image 610 - Confidence: 0.9996
# Test Image 611 - Confidence: 0.9966
# Test Image 612 - Confidence: 0.5403
# Test Image 613 - Confidence: 0.9992
